# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Inverted Index** - A mapping from terms (words) to the list of document IDs containing those terms.

# %% [markdown]
# # **Question 01** - **Part A**

# %%
import os
def build_inverted_index(folder_path): # Define function with folder path as input
    inverted_index = {} # Create empty dictionary to store word → list of document IDs

    for filename in os.listdir(folder_path): # Loop through all files in the given folder
        file_path = os.path.join(folder_path, filename) # Create full path to the file
        doc_id = filename.split('.')[0] # Use filename (without extension) as document ID

        with open(file_path, 'r', encoding='utf-8') as file: # Open and read the file
          content = file.read() # Read entire text from file content
          words = content.split() # Split into individual words

          for word in words: # For each word, update the inverted index
              if word not in inverted_index: # If word not already in dictionary
                  inverted_index[word] = []  # Create empty list for new word

              if doc_id not in inverted_index[word]: # If document ID not already listed
                  inverted_index[word].append(doc_id) # Add document ID to the word’s list

    return inverted_index # Return the complete inverted index

# %%
folder_path = '/content/drive/MyDrive/IRWA/inverted' # Path to folder containing text files
inverted_index = build_inverted_index(folder_path) # Build inverted index: word → list of document IDs

# %%
inverted_index # Print the inverted index
# Out:
# {'new': ['Doc3', 'Doc4', 'Doc2'],
#  'approach': ['Doc3'],
#  'for': ['Doc3', 'Doc4', 'Doc1'],
#  'treatment': ['Doc3'],
#  'of': ['Doc3'],
#  'schizophrenia': ['Doc3', 'Doc4', 'Doc1', 'Doc2'],
#  'hopes': ['Doc4'],
#  'patients': ['Doc4'],
#  'breakthrough': ['Doc1'],
#  'drug': ['Doc1', 'Doc2']}

# %% [markdown]
# # **Part B** -  **I**

# %%
def AND_op(list1,list2):
    return set(list1).intersection(set(list2))   # Return common items (logical AND) between two lists as a set

# %%
for key in inverted_index: # Loop through every word (key) in the inverted index
    if key=='schizophrenia':  # If the word is 'schizophrenia', store its document list in List1
        List1=inverted_index[key]
    if key=='drug': # If the word is 'drug', store its document list in List2
        List2=inverted_index[key]

# %%
print(AND_op(List1,List2))
# Out:
# {'Doc1', 'Doc2'}

# %% [markdown]
# # **II**

# %%
def OR_op(list1,list2):  # Define function to combine two lists
    return set(list1).union(set(list2))  # Return all unique elements from both lists (union)

# %%
def NOT_op(a,b): # Return elements in list b that are NOT in list a (set difference)
    return set(b)-set(a)  # Return items in b that are NOT in a (set difference)

# %%
# For each filename, split it at '.' and take the part before the extension
# Collect these as a list of document IDs without file extensions
fileList=[name.split(".")[0] for name in os.listdir(folder_path)]
fileList
# Out:
# ['Doc3', 'Doc4', 'Doc1', 'Doc2']

# %%
for key in inverted_index: # Loop through all words in the inverted index
    if key=='drug': # If the word is 'drug', get the list of documents containing 'drug' in List3
        List3=inverted_index[key]
    if key=='approach': # If the word is 'approach', get the list of documents containing 'approach' in List4
        List4=inverted_index[key]
    if key=='for': # If the word is 'for', get the list of documents containing 'for' in List5
        List5=inverted_index[key]

# %%
List6 = OR_op(List3, List4) # Combine documents containing 'drug' OR 'approach' (union)
List7 = NOT_op(List6,fileList) # Get documents NOT containing 'drug' or 'approach' from the full file list
List8 = AND_op(List5,List7) # Find documents that contain 'for' AND do NOT contain 'drug' or 'approach'
print(List8) # Print the final list of document ID
# Out:
# {'Doc4'}

# %% [markdown]
# # **Positional Index** -  An inverted index that also stores the positions of each term in each document.

# %%
import os
def build_positional_index(folder_path): # Define function with folder path as input
    positional_index = {} # Create new dictionary: word -> {doc_id: [positions]}

    for filename in os.listdir(folder_path): # Loop through all files in the given folder
        file_path = os.path.join(folder_path, filename) # Full path to file
        doc_id = filename.split('.')[0]  # Use filename (without extension) as document ID

        with open(file_path, 'r', encoding='utf-8') as file: # Open and read the file
            content = file.read() # Read the entire file content
            words = content.split() # Split content into a list of words

            for position, word in enumerate(words, start=1): # Enumerate over words with position starting at 1
                if word not in positional_index:
                    positional_index[word] = {} # Create nested dict for the word

                if doc_id not in positional_index[word]:
                    positional_index[word][doc_id] = [] # Create list for positions

                positional_index[word][doc_id].append(position) # Append position of word in document
    return positional_index # Return the positional index dictionary

# %%
folder_path = '/content/drive/MyDrive/IRWA/positional'
positional_index = build_positional_index(folder_path)

# %%
positional_index
# Out:
# {'\ufeffRemarks': {'doc_1': [1], 'doc_3': [1]},
#  'circus': {'doc_1': [2]},
#  'Announcing': {'doc_1': [3]},
#  'Candidacy': {'doc_1': [4]},
#  'for': {'doc_1': [5],
#   'doc_3': [13, 26, 30, 51, 201, 254],
#   'doc_2': [93, 138, 142, 260, 262, 265]},
#  'President': {'doc_1': [6], 'doc_3': [219, 302]},
#  'in': {'doc_1': [7, 42, 118, 148, 201],
#   'doc_3': [10, 295, 305, 308, 355],
#   'doc_2': [7, 106, 126, 216, 242, 294, 300]},
#  'New': {'doc_1': [8, 46], 'doc_2': [48]},
#  'York': {'doc_1': [9], 'doc_2': [49]},
#  'City': {'doc_1': [10], 'doc_2': [50]},
#  'Trump:': {'doc_1': [11]},
#  'Wow.': {'doc_1': [12]},
#  'Whoa.': {'doc_1': [13]},
#  'That': {'doc_1': [14], 'doc_3': [124]},
#  'is': {'doc_1': [15, 57, 117],
#   'doc_3': [69],
#   'doc_2': [229, 258, 274, 328, 333, 348]},
#  'some': {'doc_1': [16, 70]},
#  'group': {'doc_1': [17]},
#  'of': {'doc_1': [18, 71],
#   'doc_3': [76, 114, 129, 145, 218, 311, 347],
#   'doc_2': [28, 60, 98, 103, 115, 128, 199, 222, 268, 283]},
#  'people.': {'doc_1': [19]},
#  'Thousands.So': {'doc_1': [20]},
#  'nice,': {'doc_1': [21]},
#  'thank': {'doc_1': [22], 'doc_3': [21]},
#  'you': {'doc_1': [23, 197],
#   'doc_3': [12, 22],
#   'doc_2': [13, 19, 172, 191, 341]},
#  'very': {'doc_1': [24], 'doc_2': [14, 135]},
#  'much.': {'doc_1': [25], 'doc_2': [15]},
#  "That's": {'doc_1': [26], 'doc_2': [175]},
#  'really': {'doc_1': [27]},
#  'nice.': {'doc_1': [28]},
#  'Thank': {'doc_1': [29], 'doc_2': [12, 237]},
#  'you.': {'doc_1': [30], 'doc_2': [224, 238]},
#  "It's": {'doc_1': [31, 38], 'doc_3': [80]},
#  'great': {'doc_1': [32, 39], 'doc_2': [301]},
#  'to': {'doc_1': [33, 40, 52, 106, 128],
#   'doc_3': [16,
#    18,
#    23,
#    39,
#    44,
#    71,
#    82,
#    102,
#    149,
#    164,
#    214,
#    249,
#    268,
#    284,
#    297,
#    299,
#    301,
#    316,
#    329],
#   'doc_2': [18, 33, 37, 78, 119, 169, 171, 188, 190, 230, 335]},
#  'be': {'doc_1': [34, 41], 'doc_3': [126, 139, 165]},
#  'at': {'doc_1': [35, 177], 'doc_3': [5, 371], 'doc_2': [2, 100]},
#  'Trump': {'doc_1': [36]},
#  'Tower.': {'doc_1': [37]},
#  'a': {'doc_1': [43, 149, 199],
#   'doc_3': [46, 103, 162, 251, 255, 357],
#   'doc_2': [22, 31, 134, 244, 319]},
#  'wonderful': {'doc_1': [44]},
#  'city,': {'doc_1': [45]},
#  'York.': {'doc_1': [47]},
#  'And': {'doc_1': [48]},
#  "it's": {'doc_1': [49, 112], 'doc_2': [318]},
#  'an': {'doc_1': [50]},
#  'honor': {'doc_1': [51]},
#  'have': {'doc_1': [53, 99, 123, 129, 134],
#   'doc_3': [161, 314],
#   'doc_2': [240]},
#  'everybody': {'doc_1': [54]},
#  'here.': {'doc_1': [55]},
#  'This': {'doc_1': [56]},
#  'beyond': {'doc_1': [58]},
#  "anybody's": {'doc_1': [59]},
#  'expectations.': {'doc_1': [60]},
#  "There's": {'doc_1': [61]},
#  'been': {'doc_1': [62], 'doc_2': [241]},
#  'no': {'doc_1': [63], 'doc_3': [351], 'doc_2': [181]},
#  'crowd': {'doc_1': [64]},
#  'like': {'doc_1': [65, 86], 'doc_3': [38]},
#  'this.And,': {'doc_1': [66]},
#  'I': {'doc_1': [67, 109, 155],
#   'doc_3': [36, 94, 133],
#   'doc_2': [16, 84, 89, 110, 152, 155, 162, 164, 185, 194, 239, 247, 303]},
#  'can': {'doc_1': [68], 'doc_2': [351]},
#  'tell,': {'doc_1': [69]},
#  'the': {'doc_1': [72, 80, 91, 138, 159, 162, 185, 194],
#   'doc_3': [6,
#    14,
#    24,
#    27,
#    73,
#    90,
#    112,
#    115,
#    127,
#    140,
#    169,
#    173,
#    180,
#    183,
#    189,
#    216,
#    237,
#    306,
#    318,
#    325,
#    337],
#   'doc_2': [3,
#    39,
#    45,
#    56,
#    70,
#    91,
#    101,
#    104,
#    107,
#    112,
#    116,
#    122,
#    129,
#    157,
#    197,
#    213,
#    217,
#    220,
#    232,
#    266,
#    269,
#    278,
#    326,
#    353,
#    358,
#    364]},
#  'candidates,': {'doc_1': [73]},
#  'they': {'doc_1': [74, 97, 104], 'doc_3': [365], 'doc_2': [66, 350]},
#  'went': {'doc_1': [75], 'doc_3': [262, 292]},
#  'in.': {'doc_1': [76]},
#  'They': {'doc_1': [77, 84, 152, 179]},
#  "didn't": {'doc_1': [78, 82, 89, 98], 'doc_2': [165]},
#  'know': {'doc_1': [79, 90], 'doc_2': [248]},
#  'air-conditioner': {'doc_1': [81]},
#  'work.': {'doc_1': [83]},
#  'sweated': {'doc_1': [85]},
#  'dogs.': {'doc_1': [87]},
#  '[laughter]They': {'doc_1': [88]},
#  'room': {'doc_1': [92]},
#  'was': {'doc_1': [93, 137, 193], 'doc_3': [275], 'doc_2': [111, 133]},
#  'too': {'doc_1': [94]},
#  'big,': {'doc_1': [95]},
#  'because': {'doc_1': [96], 'doc_2': [88, 338]},
#  'anybody': {'doc_1': [100, 141], 'doc_2': [311]},
#  'there.': {'doc_1': [101]},
#  'How': {'doc_1': [102]},
#  'are': {'doc_1': [103]},
#  'going': {'doc_1': [105], 'doc_2': [334]},
#  'beat': {'doc_1': [107, 156, 175], 'doc_3': [178]},
#  'ISIS?': {'doc_1': [108]},
#  "don't": {'doc_1': [110, 122, 133]},
#  'think': {'doc_1': [111]},
#  'gonna': {'doc_1': [113]},
#  'happen.': {'doc_1': [114]},
#  '[applause]Our': {'doc_1': [115]},
#  'country': {'doc_1': [116], 'doc_3': [53]},
#  'serious': {'doc_1': [119]},
#  'trouble.': {'doc_1': [120]},
#  'We': {'doc_1': [121, 126, 166, 169], 'doc_3': [160, 247, 291, 360]},
#  'victories': {'doc_1': [124]},
#  'anymore.': {'doc_1': [125]},
#  'used': {'doc_1': [127]},
#  'victories,': {'doc_1': [130]},
#  'but': {'doc_1': [131], 'doc_3': [203], 'doc_2': [35]},
#  'we': {'doc_1': [132, 174, 190],
#   'doc_3': [154, 171, 187, 204, 233, 341, 373],
#   'doc_2': [290]},
#  'them.': {'doc_1': [135]},
#  'When': {'doc_1': [136, 172, 192]},
#  'last': {'doc_1': [139, 195]},
#  'time': {'doc_1': [140, 196], 'doc_3': [70, 81, 193, 261], 'doc_2': [137]},
#  'saw': {'doc_1': [142, 198]},
#  'us': {'doc_1': [143], 'doc_3': [101]},
#  'beating,': {'doc_1': [144]},
#  "let's": {'doc_1': [145]},
#  'say,': {'doc_1': [146], 'doc_2': [305]},
#  'China': {'doc_1': [147, 157]},
#  'trade': {'doc_1': [150]},
#  'deal?': {'doc_1': [151]},
#  'kill': {'doc_1': [153]},
#  'us.': {'doc_1': [154]},
#  'all': {'doc_1': [158], 'doc_3': [122, 334], 'doc_2': [59, 179]},
#  'time.': {'doc_1': [160, 163], 'doc_3': [257]},
#  'All': {'doc_1': [161]},
#  '[applause]Audience': {'doc_1': [164]},
#  'Member:': {'doc_1': [165]},
#  'want': {'doc_1': [167, 170]},
#  'Trump.': {'doc_1': [168]},
#  'Trump.Trump:': {'doc_1': [171]},
#  'did': {'doc_1': [173], 'doc_2': [153]},
#  'Japan': {'doc_1': [176]},
#  'anything?': {'doc_1': [178]},
#  'send': {'doc_1': [180]},
#  'their': {'doc_1': [181]},
#  'cars': {'doc_1': [182]},
#  'over': {'doc_1': [183]},
#  'by': {'doc_1': [184], 'doc_2': [69, 308, 360]},
#  'millions,': {'doc_1': [186]},
#  'and': {'doc_1': [187],
#   'doc_3': [20, 64, 86, 118, 142, 182, 207, 271, 279, 281, 322, 331, 367],
#   'doc_2': [25, 51, 54, 65, 140, 159, 209, 251, 264, 289, 355]},
#  'what': {'doc_1': [188], 'doc_3': [232, 363, 372], 'doc_2': [176]},
#  'do': {'doc_1': [189]},
#  'do?': {'doc_1': [191]},
#  'Chevrolet': {'doc_1': [200]},
#  'Tokyo?': {'doc_1': [202]},
#  'It': {'doc_1': [203], 'doc_3': [68, 333], 'doc_2': [132]},
#  "doesn't": {'doc_1': [204]},
#  'exist,': {'doc_1': [205]},
#  'folks.': {'doc_1': [206]},
#  'on': {'doc_3': [2], 'doc_2': [47, 52, 58, 196]},
#  'Foreign': {'doc_3': [3]},
#  'Policy': {'doc_3': [4], 'doc_2': [5]},
#  'National': {'doc_3': [7, 28]},
#  'Press': {'doc_3': [8]},
#  'Club': {'doc_3': [9]},
#  'Washington,Thank': {'doc_3': [11]},
#  'opportunity': {'doc_3': [15]},
#  'speak': {'doc_3': [17], 'doc_2': [17, 189]},
#  'you,': {'doc_3': [19], 'doc_2': [255]},
#  'Center': {'doc_3': [25]},
#  'Interest': {'doc_3': [29]},
#  'honoring': {'doc_3': [31]},
#  'me': {'doc_3': [32], 'doc_2': [253]},
#  'with': {'doc_3': [33, 59, 62, 66, 277, 336],
#   'doc_2': [81, 202, 235, 285, 325]},
#  'this': {'doc_3': [34, 192, 226, 282], 'doc_2': [150, 256, 298]},
#  'invitation.': {'doc_3': [35]},
#  'would': {'doc_3': [37], 'doc_2': [304]},
#  'talk': {'doc_3': [40]},
#  'today': {'doc_3': [41, 97], 'doc_2': [20]},
#  'about': {'doc_3': [42], 'doc_2': [173, 192]},
#  'how': {'doc_3': [43]},
#  'develop': {'doc_3': [45, 250]},
#  'new': {'doc_3': [47, 84, 87, 252, 256]},
#  'foreign': {'doc_3': [48, 78, 107, 241, 265, 286]},
#  'policy': {'doc_3': [49, 108, 242, 266, 287]},
#  'direction': {'doc_3': [50, 93]},
#  'our': {'doc_3': [52, 151, 240, 264], 'doc_2': [203, 206, 210]},
#  '\x96': {'doc_3': [54]},
#  'one': {'doc_3': [55, 285], 'doc_2': [227]},
#  'that': {'doc_3': [56, 132, 340, 349], 'doc_2': [63, 331, 349]},
#  'replaces': {'doc_3': [57]},
#  'randomness': {'doc_3': [58]},
#  'purpose,': {'doc_3': [60]},
#  'ideology': {'doc_3': [61]},
#  'strategy,': {'doc_3': [63]},
#  'chaos': {'doc_3': [65]},
#  'peace.': {'doc_3': [67]},
#  'shake': {'doc_3': [72]},
#  'rust': {'doc_3': [74]},
#  'off': {'doc_3': [75, 245]},
#  "America's": {'doc_3': [77]},
#  'policy.': {'doc_3': [79]},
#  'invite': {'doc_3': [83]},
#  'voices': {'doc_3': [85]},
#  'visions': {'doc_3': [88]},
#  'into': {'doc_3': [89, 320]},
#  'fold.': {'doc_3': [91]},
#  'The': {'doc_3': [92, 175, 197], 'doc_2': [322, 345]},
#  'will': {'doc_3': [95, 98, 109, 125, 134, 138, 229]},
#  'outline': {'doc_3': [96]},
#  'also': {'doc_3': [99]},
#  'return': {'doc_3': [100]},
#  'timeless': {'doc_3': [104]},
#  'principle.': {'doc_3': [105]},
#  'My': {'doc_3': [106], 'doc_2': [225]},
#  'always': {'doc_3': [110]},
#  'put': {'doc_3': [111]},
#  'interests': {'doc_3': [113]},
#  'American': {'doc_3': [116, 119], 'doc_2': [200]},
#  'people,': {'doc_3': [117]},
#  'security,': {'doc_3': [120]},
#  'above': {'doc_3': [121]},
#  'else.': {'doc_3': [123]},
#  'foundation': {'doc_3': [128]},
#  'every': {'doc_3': [130]},
#  'decision': {'doc_3': [131]},
#  'make.': {'doc_3': [135]},
#  'America': {'doc_3': [136]},
#  'First': {'doc_3': [137]},
#  'major': {'doc_3': [141]},
#  'overriding': {'doc_3': [143]},
#  'theme': {'doc_3': [144]},
#  'my': {'doc_3': [146], 'doc_2': [86]},
#  'administration.': {'doc_3': [147]},
#  'But': {'doc_3': [148]},
#  'chart': {'doc_3': [150]},
#  'path': {'doc_3': [152]},
#  'forward,': {'doc_3': [153]},
#  'must': {'doc_3': [155]},
#  'first': {'doc_3': [156]},
#  'briefly': {'doc_3': [157]},
#  'look': {'doc_3': [158]},
#  'back.': {'doc_3': [159]},
#  'lot': {'doc_3': [163]},
#  'proud': {'doc_3': [166]},
#  'of.': {'doc_3': [167]},
#  'In': {'doc_3': [168, 258]},
#  '1940s': {'doc_3': [170]},
#  'saved': {'doc_3': [172, 188]},
#  'world.': {'doc_3': [174]},
#  'Greatest': {'doc_3': [176]},
#  'Generation': {'doc_3': [177]},
#  'back': {'doc_3': [179]},
#  'Nazis': {'doc_3': [181]},
#  'Japanese': {'doc_3': [184]},
#  'Imperialists.': {'doc_3': [185]},
#  'Then': {'doc_3': [186]},
#  'world': {'doc_3': [190]},
#  'again,': {'doc_3': [191]},
#  'from': {'doc_3': [194, 293]},
#  'totalitarian': {'doc_3': [195]},
#  'Communism.': {'doc_3': [196]},
#  'Cold': {'doc_3': [198, 238]},
#  'War': {'doc_3': [199]},
#  'lasted': {'doc_3': [200]},
#  'decades,': {'doc_3': [202]},
#  'won.': {'doc_3': [205]},
#  'Democrats': {'doc_3': [206]},
#  'Republicans': {'doc_3': [208]},
#  'working': {'doc_3': [209]},
#  'together': {'doc_3': [210]},
#  'got': {'doc_3': [211]},
#  'Mr.': {'doc_3': [212]},
#  'Gorbachev': {'doc_3': [213]},
#  'heed': {'doc_3': [215]},
#  'words': {'doc_3': [217]},
#  'Reagan': {'doc_3': [220]},
#  'when': {'doc_3': [221]},
#  'he': {'doc_3': [222]},
#  'said:': {'doc_3': [223]},
#  '"tear': {'doc_3': [224]},
#  'down': {'doc_3': [225], 'doc_2': [149]},
#  'wall."': {'doc_3': [227]},
#  'History': {'doc_3': [228]},
#  'not': {'doc_3': [230], 'doc_2': [36, 329]},
#  'forget': {'doc_3': [231]},
#  'did.': {'doc_3': [234]},
#  'Unfortunately,': {'doc_3': [235]},
#  'after': {'doc_3': [236, 289], 'doc_2': [44]},
#  'War,': {'doc_3': [239]},
#  'veered': {'doc_3': [243]},
#  'badly': {'doc_3': [244]},
#  'course.': {'doc_3': [246]},
#  'failed': {'doc_3': [248]},
#  'vision': {'doc_3': [253]},
#  'fact,': {'doc_3': [259]},
#  'as': {'doc_3': [260], 'doc_2': [21, 340]},
#  'on,': {'doc_3': [263]},
#  'began': {'doc_3': [267, 335]},
#  'make': {'doc_3': [269, 343]},
#  'less': {'doc_3': [270, 272]},
#  'sense.': {'doc_3': [273]},
#  'Logic': {'doc_3': [274]},
#  'replaced': {'doc_3': [276]},
#  'foolishness': {'doc_3': [278]},
#  'arrogance,': {'doc_3': [280]},
#  'led': {'doc_3': [283]},
#  'disaster': {'doc_3': [288]},
#  'another.': {'doc_3': [290]},
#  'mistakes': {'doc_3': [294]},
#  'Iraq': {'doc_3': [296]},
#  'Egypt': {'doc_3': [298]},
#  'Libya,': {'doc_3': [300]},
#  "Obama's": {'doc_3': [303]},
#  'line': {'doc_3': [304]},
#  'sand': {'doc_3': [307]},
#  'Syria.': {'doc_3': [309]},
#  'Each': {'doc_3': [310]},
#  'these': {'doc_3': [312]},
#  'actions': {'doc_3': [313]},
#  'helped': {'doc_3': [315]},
#  'throw': {'doc_3': [317]},
#  'region': {'doc_3': [319]},
#  'chaos,': {'doc_3': [321]},
#  'gave': {'doc_3': [323]},
#  'ISIS': {'doc_3': [324]},
#  'space': {'doc_3': [326]},
#  'it': {'doc_3': [327], 'doc_2': [343]},
#  'needs': {'doc_3': [328]},
#  'grow': {'doc_3': [330]},
#  'prosper.': {'doc_3': [332]},
#  'dangerous': {'doc_3': [338], 'doc_2': [136]},
#  'idea': {'doc_3': [339]},
#  'could': {'doc_3': [342]},
#  'Western': {'doc_3': [344, 358]},
#  'democracies': {'doc_3': [345]},
#  'out': {'doc_3': [346], 'doc_2': [363]},
#  'countries': {'doc_3': [348]},
#  'had': {'doc_3': [350, 366]},
#  'experience': {'doc_3': [352]},
#  'or': {'doc_3': [353]},
#  'interest': {'doc_3': [354]},
#  'becoming': {'doc_3': [356]},
#  'Democracy.': {'doc_3': [359]},
#  'tore': {'doc_3': [361]},
#  'up': {'doc_3': [362]},
#  'institutions': {'doc_3': [364]},
#  'then': {'doc_3': [368]},
#  'were': {'doc_3': [369], 'doc_2': [67]},
#  'surprised': {'doc_3': [370]},
#  'unleashed.': {'doc_3': [374]},
#  'Remarks': {'doc_2': [1]},
#  'AIPAC': {'doc_2': [4]},
#  'Conference': {'doc_2': [6]},
#  'Washington,': {'doc_2': [8]},
#  'DC': {'doc_2': [9]},
#  'Good': {'doc_2': [10]},
#  'evening.': {'doc_2': [11]},
#  'lifelong': {'doc_2': [23]},
#  'supporter': {'doc_2': [24]},
#  'true': {'doc_2': [26]},
#  'friend': {'doc_2': [27]},
#  'Israel.': {'doc_2': [29, 145, 174]},
#  "I'm": {'doc_2': [30, 160]},
#  'newcomer': {'doc_2': [32]},
#  'politics,': {'doc_2': [34]},
#  'backing': {'doc_2': [38]},
#  'Jewish': {'doc_2': [40, 130]},
#  'state.In': {'doc_2': [41]},
#  '2001,': {'doc_2': [42]},
#  'weeks': {'doc_2': [43]},
#  'attacks': {'doc_2': [46, 57, 62]},
#  'Washington': {'doc_2': [53]},
#  'frankly,': {'doc_2': [55, 141]},
#  'us,': {'doc_2': [61]},
#  'perpetrated': {'doc_2': [64, 68]},
#  'Islamic': {'doc_2': [71]},
#  'fundamentalists,': {'doc_2': [72]},
#  'Mayor': {'doc_2': [73]},
#  'Rudy': {'doc_2': [74]},
#  'Giuliani': {'doc_2': [75]},
#  'visited': {'doc_2': [76]},
#  'Israel': {'doc_2': [77, 94, 120, 263]},
#  'show': {'doc_2': [79]},
#  'solidarity': {'doc_2': [80]},
#  'terror': {'doc_2': [82, 284]},
#  'victims.': {'doc_2': [83]},
#  'sent': {'doc_2': [85]},
#  'plane,': {'doc_2': [87]},
#  'backed': {'doc_2': [90]},
#  'mission': {'doc_2': [92]},
#  '100': {'doc_2': [95]},
#  'percent.In': {'doc_2': [96]},
#  'spring': {'doc_2': [97]},
#  '2004,': {'doc_2': [99]},
#  'height': {'doc_2': [102]},
#  'violence': {'doc_2': [105]},
#  'Gaza': {'doc_2': [108]},
#  'Strip,': {'doc_2': [109]},
#  'grand': {'doc_2': [113]},
#  'marshal': {'doc_2': [114]},
#  '40th': {'doc_2': [117]},
#  'Salute': {'doc_2': [118]},
#  'parade,': {'doc_2': [121]},
#  'largest': {'doc_2': [123]},
#  'single': {'doc_2': [124]},
#  'gathering': {'doc_2': [125]},
#  'support': {'doc_2': [127]},
#  'state.': {'doc_2': [131]},
#  'Israel,': {'doc_2': [139]},
#  'anyone': {'doc_2': [143]},
#  'supporting': {'doc_2': [144]},
#  'Many': {'doc_2': [146]},
#  'people': {'doc_2': [147]},
#  'turned': {'doc_2': [148]},
#  'honor;': {'doc_2': [151]},
#  'not.': {'doc_2': [154]},
#  'took': {'doc_2': [156]},
#  'risk': {'doc_2': [158]},
#  'glad': {'doc_2': [161]},
#  'did.But': {'doc_2': [163]},
#  'come': {'doc_2': [166]},
#  'here': {'doc_2': [167, 187, 273]},
#  'tonight': {'doc_2': [168]},
#  'pander': {'doc_2': [170]},
#  'politicians': {'doc_2': [177]},
#  'do,': {'doc_2': [178]},
#  'talk,': {'doc_2': [180]},
#  'action,': {'doc_2': [182]},
#  'believe': {'doc_2': [183, 313, 316]},
#  'me.': {'doc_2': [184]},
#  'came': {'doc_2': [186]},
#  'where': {'doc_2': [193]},
#  'stand': {'doc_2': [195]},
#  'future': {'doc_2': [198]},
#  'relations': {'doc_2': [201]},
#  'strategic': {'doc_2': [204]},
#  'ally,': {'doc_2': [205]},
#  'unbreakable': {'doc_2': [207]},
#  'friendship': {'doc_2': [208]},
#  'cultural': {'doc_2': [211]},
#  'brother,': {'doc_2': [212]},
#  'only': {'doc_2': [214]},
#  'democracy': {'doc_2': [215]},
#  'Middle': {'doc_2': [218, 270]},
#  'East,': {'doc_2': [219]},
#  'State': {'doc_2': [221]},
#  'Israel.Thank': {'doc_2': [223]},
#  'number': {'doc_2': [226]},
#  'priority': {'doc_2': [228]},
#  'dismantle': {'doc_2': [231]},
#  'disastrous': {'doc_2': [233]},
#  'deal': {'doc_2': [234, 249, 257, 327]},
#  'Iran.': {'doc_2': [236]},
#  'business': {'doc_2': [243]},
#  'long': {'doc_2': [245]},
#  'time,': {'doc_2': [246]},
#  'making': {'doc_2': [250]},
#  'let': {'doc_2': [252]},
#  'tell': {'doc_2': [254]},
#  'catastrophic': {'doc_2': [259]},
#  'America,': {'doc_2': [261]},
#  'whole': {'doc_2': [267]},
#  'East.The': {'doc_2': [271]},
#  'problem': {'doc_2': [272, 347]},
#  'fundamental.': {'doc_2': [275]},
#  "We've": {'doc_2': [276]},
#  'rewarded': {'doc_2': [277]},
#  "world's": {'doc_2': [279]},
#  'leading': {'doc_2': [280]},
#  'state': {'doc_2': [281]},
#  'sponsor': {'doc_2': [282]},
#  '150': {'doc_2': [286]},
#  'billion': {'doc_2': [287]},
#  'dollars': {'doc_2': [288]},
#  'received': {'doc_2': [291]},
#  'absolutely': {'doc_2': [292]},
#  'nothing': {'doc_2': [293]},
#  'return.': {'doc_2': [295]},
#  "I've": {'doc_2': [296]},
#  'studied': {'doc_2': [297]},
#  'issue': {'doc_2': [299]},
#  'detail.': {'doc_2': [302]},
#  'actually,': {'doc_2': [306]},
#  'greater': {'doc_2': [307]},
#  'far': {'doc_2': [309]},
#  'than': {'doc_2': [310]},
#  'else,': {'doc_2': [312]},
#  'me,': {'doc_2': [314]},
#  'oh,': {'doc_2': [315]},
#  'me.And': {'doc_2': [317]},
#  'bad': {'doc_2': [320]},
#  'deal.': {'doc_2': [321]},
#  'biggest': {'doc_2': [323]},
#  'concern': {'doc_2': [324]},
#  'necessarily': {'doc_2': [330]},
#  'Iran': {'doc_2': [332]},
#  'violate': {'doc_2': [336]},
#  'it,': {'doc_2': [337]},
#  'already': {'doc_2': [339]},
#  'know,': {'doc_2': [342]},
#  'has.': {'doc_2': [344]},
#  'bigger': {'doc_2': [346]},
#  'keep': {'doc_2': [352]},
#  'terms': {'doc_2': [354]},
#  'still': {'doc_2': [356]},
#  'get': {'doc_2': [357]},
#  'bomb': {'doc_2': [359]},
#  'simply': {'doc_2': [361]},
#  'running': {'doc_2': [362]},
#  'clock.': {'doc_2': [365]}}

# %%
import os
import string

def build_positional_index(folder_path):
    positional_index = {}  # word -> {doc_id: [positions]}

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        doc_id = filename.split('.')[0]  # document ID from filename

        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

            # Lowercase and remove punctuation
            translator = str.maketrans('', '', string.punctuation)
            words = content.lower().translate(translator).split()

            for position, word in enumerate(words, start=1):
                if word not in positional_index:
                    positional_index[word] = {}

                if doc_id not in positional_index[word]:
                    positional_index[word][doc_id] = []

                positional_index[word][doc_id].append(position)

    return positional_index

# %%
folder_path = '/content/drive/MyDrive/IRWA/positional'
positional_index = build_positional_index(folder_path)

# %%
positional_index
# Out:
# {'Remarks': {'doc_1': [1], 'doc_2': [1], 'doc_3': [1]},
#  'circus': {'doc_1': [2]},
#  'Announcing': {'doc_1': [3]},
#  'Candidacy': {'doc_1': [4]},
#  'for': {'doc_1': [5],
#   'doc_2': [93, 138, 142, 260, 262, 265],
#   'doc_3': [13, 26, 30, 51, 201, 254]},
#  'President': {'doc_1': [6], 'doc_3': [219, 302]},
#  'in': {'doc_1': [7, 42, 118, 148, 201],
#   'doc_2': [7, 106, 126, 216, 242, 294, 300],
#   'doc_3': [10, 295, 305, 308, 355]},
#  'New': {'doc_1': [8, 46], 'doc_2': [48]},
#  'York': {'doc_1': [9], 'doc_2': [49]},
#  'City': {'doc_1': [10], 'doc_2': [50]},
#  'Trump:': {'doc_1': [11]},
#  'Wow.': {'doc_1': [12]},
#  'Whoa.': {'doc_1': [13]},
#  'That': {'doc_1': [14], 'doc_3': [124]},
#  'is': {'doc_1': [15, 57, 117],
#   'doc_2': [229, 258, 274, 328, 333, 348],
#   'doc_3': [69]},
#  'some': {'doc_1': [16, 70]},
#  'group': {'doc_1': [17]},
#  'of': {'doc_1': [18, 71],
#   'doc_2': [28, 60, 98, 103, 115, 128, 199, 222, 268, 283],
#   'doc_3': [76, 114, 129, 145, 218, 311, 347]},
#  'people.': {'doc_1': [19]},
#  'Thousands.So': {'doc_1': [20]},
#  'nice,': {'doc_1': [21]},
#  'thank': {'doc_1': [22], 'doc_3': [21]},
#  'you': {'doc_1': [23, 197],
#   'doc_2': [13, 19, 172, 191, 341],
#   'doc_3': [12, 22]},
#  'very': {'doc_1': [24], 'doc_2': [14, 135]},
#  'much.': {'doc_1': [25], 'doc_2': [15]},
#  "That's": {'doc_1': [26], 'doc_2': [175]},
#  'really': {'doc_1': [27]},
#  'nice.': {'doc_1': [28]},
#  'Thank': {'doc_1': [29], 'doc_2': [12, 237]},
#  'you.': {'doc_1': [30], 'doc_2': [224, 238]},
#  "It's": {'doc_1': [31, 38], 'doc_3': [80]},
#  'great': {'doc_1': [32, 39], 'doc_2': [301]},
#  'to': {'doc_1': [33, 40, 52, 106, 128],
#   'doc_2': [18, 33, 37, 78, 119, 169, 171, 188, 190, 230, 335],
#   'doc_3': [16,
#    18,
#    23,
#    39,
#    44,
#    71,
#    82,
#    102,
#    149,
#    164,
#    214,
#    249,
#    268,
#    284,
#    297,
#    299,
#    301,
#    316,
#    329]},
#  'be': {'doc_1': [34, 41], 'doc_3': [126, 139, 165]},
#  'at': {'doc_1': [35, 177], 'doc_2': [2, 100], 'doc_3': [5, 371]},
#  'Trump': {'doc_1': [36]},
#  'Tower.': {'doc_1': [37]},
#  'a': {'doc_1': [43, 149, 199],
#   'doc_2': [22, 31, 134, 244, 319],
#   'doc_3': [46, 103, 162, 251, 255, 357]},
#  'wonderful': {'doc_1': [44]},
#  'city,': {'doc_1': [45]},
#  'York.': {'doc_1': [47]},
#  'And': {'doc_1': [48]},
#  "it's": {'doc_1': [49, 112], 'doc_2': [318]},
#  'an': {'doc_1': [50]},
#  'honor': {'doc_1': [51]},
#  'have': {'doc_1': [53, 99, 123, 129, 134],
#   'doc_2': [240],
#   'doc_3': [161, 314]},
#  'everybody': {'doc_1': [54]},
#  'here.': {'doc_1': [55]},
#  'This': {'doc_1': [56]},
#  'beyond': {'doc_1': [58]},
#  "anybody's": {'doc_1': [59]},
#  'expectations.': {'doc_1': [60]},
#  "There's": {'doc_1': [61]},
#  'been': {'doc_1': [62], 'doc_2': [241]},
#  'no': {'doc_1': [63], 'doc_2': [181], 'doc_3': [351]},
#  'crowd': {'doc_1': [64]},
#  'like': {'doc_1': [65, 86], 'doc_3': [38]},
#  'this.And,': {'doc_1': [66]},
#  'I': {'doc_1': [67, 109, 155],
#   'doc_2': [16, 84, 89, 110, 152, 155, 162, 164, 185, 194, 239, 247, 303],
#   'doc_3': [36, 94, 133]},
#  'can': {'doc_1': [68], 'doc_2': [351]},
#  'tell,': {'doc_1': [69]},
#  'the': {'doc_1': [72, 80, 91, 138, 159, 162, 185, 194],
#   'doc_2': [3,
#    39,
#    45,
#    56,
#    70,
#    91,
#    101,
#    104,
#    107,
#    112,
#    116,
#    122,
#    129,
#    157,
#    197,
#    213,
#    217,
#    220,
#    232,
#    266,
#    269,
#    278,
#    326,
#    353,
#    358,
#    364],
#   'doc_3': [6,
#    14,
#    24,
#    27,
#    73,
#    90,
#    112,
#    115,
#    127,
#    140,
#    169,
#    173,
#    180,
#    183,
#    189,
#    216,
#    237,
#    306,
#    318,
#    325,
#    337]},
#  'candidates,': {'doc_1': [73]},
#  'they': {'doc_1': [74, 97, 104], 'doc_2': [66, 350], 'doc_3': [365]},
#  'went': {'doc_1': [75], 'doc_3': [262, 292]},
#  'in.': {'doc_1': [76]},
#  'They': {'doc_1': [77, 84, 152, 179]},
#  "didn't": {'doc_1': [78, 82, 89, 98], 'doc_2': [165]},
#  'know': {'doc_1': [79, 90], 'doc_2': [248]},
#  'air-conditioner': {'doc_1': [81]},
#  'work.': {'doc_1': [83]},
#  'sweated': {'doc_1': [85]},
#  'dogs.': {'doc_1': [87]},
#  '[laughter]They': {'doc_1': [88]},
#  'room': {'doc_1': [92]},
#  'was': {'doc_1': [93, 137, 193], 'doc_2': [111, 133], 'doc_3': [275]},
#  'too': {'doc_1': [94]},
#  'big,': {'doc_1': [95]},
#  'because': {'doc_1': [96], 'doc_2': [88, 338]},
#  'anybody': {'doc_1': [100, 141], 'doc_2': [311]},
#  'there.': {'doc_1': [101]},
#  'How': {'doc_1': [102]},
#  'are': {'doc_1': [103]},
#  'going': {'doc_1': [105], 'doc_2': [334]},
#  'beat': {'doc_1': [107, 156, 175], 'doc_3': [178]},
#  'ISIS?': {'doc_1': [108]},
#  "don't": {'doc_1': [110, 122, 133]},
#  'think': {'doc_1': [111]},
#  'gonna': {'doc_1': [113]},
#  'happen.': {'doc_1': [114]},
#  '[applause]Our': {'doc_1': [115]},
#  'country': {'doc_1': [116], 'doc_3': [53]},
#  'serious': {'doc_1': [119]},
#  'trouble.': {'doc_1': [120]},
#  'We': {'doc_1': [121, 126, 166, 169], 'doc_3': [160, 247, 291, 360]},
#  'victories': {'doc_1': [124]},
#  'anymore.': {'doc_1': [125]},
#  'used': {'doc_1': [127]},
#  'victories,': {'doc_1': [130]},
#  'but': {'doc_1': [131], 'doc_2': [35], 'doc_3': [203]},
#  'we': {'doc_1': [132, 174, 190],
#   'doc_2': [290],
#   'doc_3': [154, 171, 187, 204, 233, 341, 373]},
#  'them.': {'doc_1': [135]},
#  'When': {'doc_1': [136, 172, 192]},
#  'last': {'doc_1': [139, 195]},
#  'time': {'doc_1': [140, 196], 'doc_2': [137], 'doc_3': [70, 81, 193, 261]},
#  'saw': {'doc_1': [142, 198]},
#  'us': {'doc_1': [143], 'doc_3': [101]},
#  'beating,': {'doc_1': [144]},
#  "let's": {'doc_1': [145]},
#  'say,': {'doc_1': [146], 'doc_2': [305]},
#  'China': {'doc_1': [147, 157]},
#  'trade': {'doc_1': [150]},
#  'deal?': {'doc_1': [151]},
#  'kill': {'doc_1': [153]},
#  'us.': {'doc_1': [154]},
#  'all': {'doc_1': [158], 'doc_2': [59, 179], 'doc_3': [122, 334]},
#  'time.': {'doc_1': [160, 163], 'doc_3': [257]},
#  'All': {'doc_1': [161]},
#  '[applause]Audience': {'doc_1': [164]},
#  'Member:': {'doc_1': [165]},
#  'want': {'doc_1': [167, 170]},
#  'Trump.': {'doc_1': [168]},
#  'Trump.Trump:': {'doc_1': [171]},
#  'did': {'doc_1': [173], 'doc_2': [153]},
#  'Japan': {'doc_1': [176]},
#  'anything?': {'doc_1': [178]},
#  'send': {'doc_1': [180]},
#  'their': {'doc_1': [181]},
#  'cars': {'doc_1': [182]},
#  'over': {'doc_1': [183]},
#  'by': {'doc_1': [184], 'doc_2': [69, 308, 360]},
#  'millions,': {'doc_1': [186]},
#  'and': {'doc_1': [187],
#   'doc_2': [25, 51, 54, 65, 140, 159, 209, 251, 264, 289, 355],
#   'doc_3': [20, 64, 86, 118, 142, 182, 207, 271, 279, 281, 322, 331, 367]},
#  'what': {'doc_1': [188], 'doc_2': [176], 'doc_3': [232, 363, 372]},
#  'do': {'doc_1': [189]},
#  'do?': {'doc_1': [191]},
#  'Chevrolet': {'doc_1': [200]},
#  'Tokyo?': {'doc_1': [202]},
#  'It': {'doc_1': [203], 'doc_2': [132], 'doc_3': [68, 333]},
#  "doesn't": {'doc_1': [204]},
#  'exist,': {'doc_1': [205]},
#  'folks.': {'doc_1': [206]},
#  'AIPAC': {'doc_2': [4]},
#  'Policy': {'doc_2': [5], 'doc_3': [4]},
#  'Conference': {'doc_2': [6]},
#  'Washington,': {'doc_2': [8]},
#  'DC': {'doc_2': [9]},
#  'Good': {'doc_2': [10]},
#  'evening.': {'doc_2': [11]},
#  'speak': {'doc_2': [17, 189], 'doc_3': [17]},
#  'today': {'doc_2': [20], 'doc_3': [41, 97]},
#  'as': {'doc_2': [21, 340], 'doc_3': [260]},
#  'lifelong': {'doc_2': [23]},
#  'supporter': {'doc_2': [24]},
#  'true': {'doc_2': [26]},
#  'friend': {'doc_2': [27]},
#  'Israel.': {'doc_2': [29, 145, 174]},
#  "I'm": {'doc_2': [30, 160]},
#  'newcomer': {'doc_2': [32]},
#  'politics,': {'doc_2': [34]},
#  'not': {'doc_2': [36, 329], 'doc_3': [230]},
#  'backing': {'doc_2': [38]},
#  'Jewish': {'doc_2': [40, 130]},
#  'state.In': {'doc_2': [41]},
#  '2001,': {'doc_2': [42]},
#  'weeks': {'doc_2': [43]},
#  'after': {'doc_2': [44], 'doc_3': [236, 289]},
#  'attacks': {'doc_2': [46, 57, 62]},
#  'on': {'doc_2': [47, 52, 58, 196], 'doc_3': [2]},
#  'Washington': {'doc_2': [53]},
#  'frankly,': {'doc_2': [55, 141]},
#  'us,': {'doc_2': [61]},
#  'that': {'doc_2': [63, 331, 349], 'doc_3': [56, 132, 340, 349]},
#  'perpetrated': {'doc_2': [64, 68]},
#  'were': {'doc_2': [67], 'doc_3': [369]},
#  'Islamic': {'doc_2': [71]},
#  'fundamentalists,': {'doc_2': [72]},
#  'Mayor': {'doc_2': [73]},
#  'Rudy': {'doc_2': [74]},
#  'Giuliani': {'doc_2': [75]},
#  'visited': {'doc_2': [76]},
#  'Israel': {'doc_2': [77, 94, 120, 263]},
#  'show': {'doc_2': [79]},
#  'solidarity': {'doc_2': [80]},
#  'with': {'doc_2': [81, 202, 235, 285, 325],
#   'doc_3': [33, 59, 62, 66, 277, 336]},
#  'terror': {'doc_2': [82, 284]},
#  'victims.': {'doc_2': [83]},
#  'sent': {'doc_2': [85]},
#  'my': {'doc_2': [86], 'doc_3': [146]},
#  'plane,': {'doc_2': [87]},
#  'backed': {'doc_2': [90]},
#  'mission': {'doc_2': [92]},
#  '100': {'doc_2': [95]},
#  'percent.In': {'doc_2': [96]},
#  'spring': {'doc_2': [97]},
#  '2004,': {'doc_2': [99]},
#  'height': {'doc_2': [102]},
#  'violence': {'doc_2': [105]},
#  'Gaza': {'doc_2': [108]},
#  'Strip,': {'doc_2': [109]},
#  'grand': {'doc_2': [113]},
#  'marshal': {'doc_2': [114]},
#  '40th': {'doc_2': [117]},
#  'Salute': {'doc_2': [118]},
#  'parade,': {'doc_2': [121]},
#  'largest': {'doc_2': [123]},
#  'single': {'doc_2': [124]},
#  'gathering': {'doc_2': [125]},
#  'support': {'doc_2': [127]},
#  'state.': {'doc_2': [131]},
#  'dangerous': {'doc_2': [136], 'doc_3': [338]},
#  'Israel,': {'doc_2': [139]},
#  'anyone': {'doc_2': [143]},
#  'supporting': {'doc_2': [144]},
#  'Many': {'doc_2': [146]},
#  'people': {'doc_2': [147]},
#  'turned': {'doc_2': [148]},
#  'down': {'doc_2': [149], 'doc_3': [225]},
#  'this': {'doc_2': [150, 256, 298], 'doc_3': [34, 192, 226, 282]},
#  'honor;': {'doc_2': [151]},
#  'not.': {'doc_2': [154]},
#  'took': {'doc_2': [156]},
#  'risk': {'doc_2': [158]},
#  'glad': {'doc_2': [161]},
#  'did.But': {'doc_2': [163]},
#  'come': {'doc_2': [166]},
#  'here': {'doc_2': [167, 187, 273]},
#  'tonight': {'doc_2': [168]},
#  'pander': {'doc_2': [170]},
#  'about': {'doc_2': [173, 192], 'doc_3': [42]},
#  'politicians': {'doc_2': [177]},
#  'do,': {'doc_2': [178]},
#  'talk,': {'doc_2': [180]},
#  'action,': {'doc_2': [182]},
#  'believe': {'doc_2': [183, 313, 316]},
#  'me.': {'doc_2': [184]},
#  'came': {'doc_2': [186]},
#  'where': {'doc_2': [193]},
#  'stand': {'doc_2': [195]},
#  'future': {'doc_2': [198]},
#  'American': {'doc_2': [200], 'doc_3': [116, 119]},
#  'relations': {'doc_2': [201]},
#  'our': {'doc_2': [203, 206, 210], 'doc_3': [52, 151, 240, 264]},
#  'strategic': {'doc_2': [204]},
#  'ally,': {'doc_2': [205]},
#  'unbreakable': {'doc_2': [207]},
#  'friendship': {'doc_2': [208]},
#  'cultural': {'doc_2': [211]},
#  'brother,': {'doc_2': [212]},
#  'only': {'doc_2': [214]},
#  'democracy': {'doc_2': [215]},
#  'Middle': {'doc_2': [218, 270]},
#  'East,': {'doc_2': [219]},
#  'State': {'doc_2': [221]},
#  'Israel.Thank': {'doc_2': [223]},
#  'My': {'doc_2': [225], 'doc_3': [106]},
#  'number': {'doc_2': [226]},
#  'one': {'doc_2': [227], 'doc_3': [55, 285]},
#  'priority': {'doc_2': [228]},
#  'dismantle': {'doc_2': [231]},
#  'disastrous': {'doc_2': [233]},
#  'deal': {'doc_2': [234, 249, 257, 327]},
#  'Iran.': {'doc_2': [236]},
#  'business': {'doc_2': [243]},
#  'long': {'doc_2': [245]},
#  'time,': {'doc_2': [246]},
#  'making': {'doc_2': [250]},
#  'let': {'doc_2': [252]},
#  'me': {'doc_2': [253], 'doc_3': [32]},
#  'tell': {'doc_2': [254]},
#  'you,': {'doc_2': [255], 'doc_3': [19]},
#  'catastrophic': {'doc_2': [259]},
#  'America,': {'doc_2': [261]},
#  'whole': {'doc_2': [267]},
#  'East.The': {'doc_2': [271]},
#  'problem': {'doc_2': [272, 347]},
#  'fundamental.': {'doc_2': [275]},
#  "We've": {'doc_2': [276]},
#  'rewarded': {'doc_2': [277]},
#  "world's": {'doc_2': [279]},
#  'leading': {'doc_2': [280]},
#  'state': {'doc_2': [281]},
#  'sponsor': {'doc_2': [282]},
#  '150': {'doc_2': [286]},
#  'billion': {'doc_2': [287]},
#  'dollars': {'doc_2': [288]},
#  'received': {'doc_2': [291]},
#  'absolutely': {'doc_2': [292]},
#  'nothing': {'doc_2': [293]},
#  'return.': {'doc_2': [295]},
#  "I've": {'doc_2': [296]},
#  'studied': {'doc_2': [297]},
#  'issue': {'doc_2': [299]},
#  'detail.': {'doc_2': [302]},
#  'would': {'doc_2': [304], 'doc_3': [37]},
#  'actually,': {'doc_2': [306]},
#  'greater': {'doc_2': [307]},
#  'far': {'doc_2': [309]},
#  'than': {'doc_2': [310]},
#  'else,': {'doc_2': [312]},
#  'me,': {'doc_2': [314]},
#  'oh,': {'doc_2': [315]},
#  'me.And': {'doc_2': [317]},
#  'bad': {'doc_2': [320]},
#  'deal.': {'doc_2': [321]},
#  'The': {'doc_2': [322, 345], 'doc_3': [92, 175, 197]},
#  'biggest': {'doc_2': [323]},
#  'concern': {'doc_2': [324]},
#  'necessarily': {'doc_2': [330]},
#  'Iran': {'doc_2': [332]},
#  'violate': {'doc_2': [336]},
#  'it,': {'doc_2': [337]},
#  'already': {'doc_2': [339]},
#  'know,': {'doc_2': [342]},
#  'it': {'doc_2': [343], 'doc_3': [327]},
#  'has.': {'doc_2': [344]},
#  'bigger': {'doc_2': [346]},
#  'keep': {'doc_2': [352]},
#  'terms': {'doc_2': [354]},
#  'still': {'doc_2': [356]},
#  'get': {'doc_2': [357]},
#  'bomb': {'doc_2': [359]},
#  'simply': {'doc_2': [361]},
#  'running': {'doc_2': [362]},
#  'out': {'doc_2': [363], 'doc_3': [346]},
#  'clock.': {'doc_2': [365]},
#  'Foreign': {'doc_3': [3]},
#  'National': {'doc_3': [7, 28]},
#  'Press': {'doc_3': [8]},
#  'Club': {'doc_3': [9]},
#  'Washington,Thank': {'doc_3': [11]},
#  'opportunity': {'doc_3': [15]},
#  'Center': {'doc_3': [25]},
#  'Interest': {'doc_3': [29]},
#  'honoring': {'doc_3': [31]},
#  'invitation.': {'doc_3': [35]},
#  'talk': {'doc_3': [40]},
#  'how': {'doc_3': [43]},
#  'develop': {'doc_3': [45, 250]},
#  'new': {'doc_3': [47, 84, 87, 252, 256]},
#  'foreign': {'doc_3': [48, 78, 107, 241, 265, 286]},
#  'policy': {'doc_3': [49, 108, 242, 266, 287]},
#  'direction': {'doc_3': [50, 93]},
#  '\x96': {'doc_3': [54]},
#  'replaces': {'doc_3': [57]},
#  'randomness': {'doc_3': [58]},
#  'purpose,': {'doc_3': [60]},
#  'ideology': {'doc_3': [61]},
#  'strategy,': {'doc_3': [63]},
#  'chaos': {'doc_3': [65]},
#  'peace.': {'doc_3': [67]},
#  'shake': {'doc_3': [72]},
#  'rust': {'doc_3': [74]},
#  'off': {'doc_3': [75, 245]},
#  "America's": {'doc_3': [77]},
#  'policy.': {'doc_3': [79]},
#  'invite': {'doc_3': [83]},
#  'voices': {'doc_3': [85]},
#  'visions': {'doc_3': [88]},
#  'into': {'doc_3': [89, 320]},
#  'fold.': {'doc_3': [91]},
#  'will': {'doc_3': [95, 98, 109, 125, 134, 138, 229]},
#  'outline': {'doc_3': [96]},
#  'also': {'doc_3': [99]},
#  'return': {'doc_3': [100]},
#  'timeless': {'doc_3': [104]},
#  'principle.': {'doc_3': [105]},
#  'always': {'doc_3': [110]},
#  'put': {'doc_3': [111]},
#  'interests': {'doc_3': [113]},
#  'people,': {'doc_3': [117]},
#  'security,': {'doc_3': [120]},
#  'above': {'doc_3': [121]},
#  'else.': {'doc_3': [123]},
#  'foundation': {'doc_3': [128]},
#  'every': {'doc_3': [130]},
#  'decision': {'doc_3': [131]},
#  'make.': {'doc_3': [135]},
#  'America': {'doc_3': [136]},
#  'First': {'doc_3': [137]},
#  'major': {'doc_3': [141]},
#  'overriding': {'doc_3': [143]},
#  'theme': {'doc_3': [144]},
#  'administration.': {'doc_3': [147]},
#  'But': {'doc_3': [148]},
#  'chart': {'doc_3': [150]},
#  'path': {'doc_3': [152]},
#  'forward,': {'doc_3': [153]},
#  'must': {'doc_3': [155]},
#  'first': {'doc_3': [156]},
#  'briefly': {'doc_3': [157]},
#  'look': {'doc_3': [158]},
#  'back.': {'doc_3': [159]},
#  'lot': {'doc_3': [163]},
#  'proud': {'doc_3': [166]},
#  'of.': {'doc_3': [167]},
#  'In': {'doc_3': [168, 258]},
#  '1940s': {'doc_3': [170]},
#  'saved': {'doc_3': [172, 188]},
#  'world.': {'doc_3': [174]},
#  'Greatest': {'doc_3': [176]},
#  'Generation': {'doc_3': [177]},
#  'back': {'doc_3': [179]},
#  'Nazis': {'doc_3': [181]},
#  'Japanese': {'doc_3': [184]},
#  'Imperialists.': {'doc_3': [185]},
#  'Then': {'doc_3': [186]},
#  'world': {'doc_3': [190]},
#  'again,': {'doc_3': [191]},
#  'from': {'doc_3': [194, 293]},
#  'totalitarian': {'doc_3': [195]},
#  'Communism.': {'doc_3': [196]},
#  'Cold': {'doc_3': [198, 238]},
#  'War': {'doc_3': [199]},
#  'lasted': {'doc_3': [200]},
#  'decades,': {'doc_3': [202]},
#  'won.': {'doc_3': [205]},
#  'Democrats': {'doc_3': [206]},
#  'Republicans': {'doc_3': [208]},
#  'working': {'doc_3': [209]},
#  'together': {'doc_3': [210]},
#  'got': {'doc_3': [211]},
#  'Mr.': {'doc_3': [212]},
#  'Gorbachev': {'doc_3': [213]},
#  'heed': {'doc_3': [215]},
#  'words': {'doc_3': [217]},
#  'Reagan': {'doc_3': [220]},
#  'when': {'doc_3': [221]},
#  'he': {'doc_3': [222]},
#  'said:': {'doc_3': [223]},
#  '"tear': {'doc_3': [224]},
#  'wall."': {'doc_3': [227]},
#  'History': {'doc_3': [228]},
#  'forget': {'doc_3': [231]},
#  'did.': {'doc_3': [234]},
#  'Unfortunately,': {'doc_3': [235]},
#  'War,': {'doc_3': [239]},
#  'veered': {'doc_3': [243]},
#  'badly': {'doc_3': [244]},
#  'course.': {'doc_3': [246]},
#  'failed': {'doc_3': [248]},
#  'vision': {'doc_3': [253]},
#  'fact,': {'doc_3': [259]},
#  'on,': {'doc_3': [263]},
#  'began': {'doc_3': [267, 335]},
#  'make': {'doc_3': [269, 343]},
#  'less': {'doc_3': [270, 272]},
#  'sense.': {'doc_3': [273]},
#  'Logic': {'doc_3': [274]},
#  'replaced': {'doc_3': [276]},
#  'foolishness': {'doc_3': [278]},
#  'arrogance,': {'doc_3': [280]},
#  'led': {'doc_3': [283]},
#  'disaster': {'doc_3': [288]},
#  'another.': {'doc_3': [290]},
#  'mistakes': {'doc_3': [294]},
#  'Iraq': {'doc_3': [296]},
#  'Egypt': {'doc_3': [298]},
#  'Libya,': {'doc_3': [300]},
#  "Obama's": {'doc_3': [303]},
#  'line': {'doc_3': [304]},
#  'sand': {'doc_3': [307]},
#  'Syria.': {'doc_3': [309]},
#  'Each': {'doc_3': [310]},
#  'these': {'doc_3': [312]},
#  'actions': {'doc_3': [313]},
#  'helped': {'doc_3': [315]},
#  'throw': {'doc_3': [317]},
#  'region': {'doc_3': [319]},
#  'chaos,': {'doc_3': [321]},
#  'gave': {'doc_3': [323]},
#  'ISIS': {'doc_3': [324]},
#  'space': {'doc_3': [326]},
#  'needs': {'doc_3': [328]},
#  'grow': {'doc_3': [330]},
#  'prosper.': {'doc_3': [332]},
#  'idea': {'doc_3': [339]},
#  'could': {'doc_3': [342]},
#  'Western': {'doc_3': [344, 358]},
#  'democracies': {'doc_3': [345]},
#  'countries': {'doc_3': [348]},
#  'had': {'doc_3': [350, 366]},
#  'experience': {'doc_3': [352]},
#  'or': {'doc_3': [353]},
#  'interest': {'doc_3': [354]},
#  'becoming': {'doc_3': [356]},
#  'Democracy.': {'doc_3': [359]},
#  'tore': {'doc_3': [361]},
#  'up': {'doc_3': [362]},
#  'institutions': {'doc_3': [364]},
#  'then': {'doc_3': [368]},
#  'surprised': {'doc_3': [370]},
#  'unleashed.': {'doc_3': [374]}}
